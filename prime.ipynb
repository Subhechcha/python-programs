# %%
lower=100
upper=1000
for num in range(lower,upper+1):
        for i in range(2,num):
            if(num%i==0):
                break
# Out:
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 101
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# 103
# ...
